# %% [markdown]
# # Deprecated — use **`Problem2_Training.ipynb`** instead
#
# This notebook previously called a script that no longer exists. Open **`colab/Problem2_Training.ipynb`** for GPU training via `python -m problem2.colab_train_all`.
